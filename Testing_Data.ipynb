# %%
import os
import cv2
import time
import pytz
import pickle
import psutil
import imutils
import datetime
import xlsxwriter
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from tabulate import tabulate
from openpyxl import load_workbook

# %%
img_test_path = r"C:\Users\SMSK_Narinda\Desktop\Research\Random_Test_Images"

# %%
#Array for saving in excel
img_num = []
img_name = []
memory_usage = []
time_taken = []
prediction = []

# %%
timezone = pytz.timezone("Asia/Jakarta")
now = timezone.localize(datetime.datetime.now())

# %%
print(timezone)
print(now)
# Out:
# Asia/Jakarta
# 2024-07-07 18:53:50.986956+07:00

# %% [markdown]
# # Testing KNN

# %%
# Load model KNN
KNNclf = r"C:\Users\SMSK_Narinda\Desktop\Skripsi_Checkpoint_KNN_SVM_Dermnet\Model\KNNClassifier.p"
modelKNN = pickle.load(open( KNNclf ,'rb'))

# %%
def extract_color_histogram(image, bins=(32,32,32)):
    # Extract 3d color by its hue, saturation, and vue (HSV)
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    hist = cv2.calcHist([hsv], [0,1,2], None, bins,
                       [0, 180, 0 , 256, 0, 256])
    
    ### handle normalizing the historigram
    if imutils.is_cv2():
        hist = cv2.normalize(hist)
    else :
        cv2.normalize(hist,hist)
        
    return hist.flatten()

# %%
print('[START]')

for idx, filename in enumerate(os.scandir(img_test_path)):
    if filename.is_file():
        print("Testing image number: ", idx+1)
        # Store image number and filename
        img_num.append(idx + 1)
        img_name.append(filename.name)
        
        # Get image's path from object filename
        image_path = filename.path
        
        # Read image from image_path 
        image = cv2.imread(image_path)
        
        # Resize image to the desired size
        image = cv2.resize(image, (128, 128))
        
        # Extract features using color histogram
        features = extract_color_histogram(image)
        
        # Measure memory and time for prediction
        current_process = psutil.Process(os.getpid())
        mem_start = current_process.memory_info().rss
        start_time = time.time()
        
        # Perform predictio
        predict = modelKNN.predict([features])
        prediction.append(predict)
        
        end_time = time.time()
        mem_end = current_process.memory_info().rss

        print("memori awal: ", mem_start)
        print("memori akhir: ", mem_end)
        
        memory_usage.append((mem_end - mem_start) / 1024)  # Memory usage in KB
        time_taken.append(end_time - start_time)  # Time taken in seconds

# Calculate average memory and time
avg_memory = sum(memory_usage) / len(memory_usage) if memory_usage else 0
avg_time = sum(time_taken) / len(time_taken) if time_taken else 0

print('[STOP]')
print("Testing completed.")
print("")
print("[RESULT]")
print(f'Average memory used per image: {avg_memory:.2f} KB')
print(f'Average time taken per image: {avg_time:.2f} seconds')
# Out:
# [START]
# Testing image number:  1
# memori awal:  12625534976
# memori akhir:  12630319104
# Testing image number:  2
# memori awal:  12630323200
# memori akhir:  12629159936
# Testing image number:  3
# memori awal:  12630179840
# memori akhir:  12630532096
# Testing image number:  4
# memori awal:  12630470656
# memori akhir:  12630740992
# Testing image number:  5
# memori awal:  12630740992
# memori akhir:  12629487616
# Testing image number:  6
# memori awal:  12629549056
# memori akhir:  12630306816
# Testing image number:  7
# memori awal:  12630343680
# memori akhir:  12629508096
# Testing image number:  8
# memori awal:  12630540288
# memori akhir:  12630552576
# Testing image number:  9
# memori awal:  12628459520
# memori akhir:  12630544384
# Testing image number:  10
# memori awal:  12630282240
# memori akhir:  12630315008
# Testing image number:  11
# memori awal:  12629262336
# memori akhir:  12628987904
# Testing image number:  12
# memori awal:  12630011904
# memori akhir:  12630269952
# Testing image number:  13
# memori awal:  12630269952
# memori akhir:  12629123072
# Testing image number:  14
# memori awal:  12629123072
# memori akhir:  12629131264
# Testing image number:  15
# memori awal:  12630163456
# memori akhir:  12630245376
# Testing image number:  16
# memori awal:  12630421504
# memori akhir:  12630421504
# Testing image number:  17
# memori awal:  12630421504
# memori akhir:  12630421504
# Testing image number:  18
# memori awal:  12630421504
# memori akhir:  12629704704
# Testing image number:  19
# memori awal:  12630724608
# memori akhir:  12630724608
# Testing image number:  20
# memori awal:  12629151744
# memori akhir:  12630237184
# Testing image number:  21
# memori awal:  12630425600
# memori akhir:  12630425600
# Testing image number:  22
# memori awal:  12630425600
# memori akhir:  12629704704
# Testing image number:  23
# memori awal:  12630720512
# memori akhir:  12630724608
# Testing image number:  24
# memori awal:  12630724608
# memori akhir:  12629151744
# Testing image number:  25
# memori awal:  12629151744
# memori akhir:  12630241280
# Testing image number:  26
# memori awal:  12630429696
# memori akhir:  12630429696
# Testing image number:  27
# memori awal:  12630429696
# memori akhir:  12630429696
# Testing image number:  28
# memori awal:  12630429696
# memori akhir:  12629708800
# Testing image number:  29
# memori awal:  12630728704
# memori akhir:  12630732800
# Testing image number:  30
# memori awal:  12629192704
# memori akhir:  12630282240
# Testing image number:  31
# memori awal:  12630421504
# memori akhir:  12630421504
# Testing image number:  32
# memori awal:  12630421504
# memori akhir:  12630929408
# Testing image number:  33
# memori awal:  12629757952
# memori akhir:  12629368832
# Testing image number:  34
# memori awal:  12630142976
# memori akhir:  12630646784
# Testing image number:  35
# memori awal:  12629360640
# memori akhir:  12630429696
# Testing image number:  36
# memori awal:  12630437888
# memori akhir:  12630437888
# Testing image number:  37
# memori awal:  12630437888
# memori akhir:  12630437888
# Testing image number:  38
# memori awal:  12630437888
# memori akhir:  12630437888
# Testing image number:  39
# memori awal:  12630441984
# memori akhir:  12630441984
# Testing image number:  40
# memori awal:  12630441984
# memori akhir:  12630454272
# Testing image number:  41
# memori awal:  12630454272
# memori akhir:  12630458368
# Testing image number:  42
# memori awal:  12630458368
# memori akhir:  12630458368
# Testing image number:  43
# memori awal:  12630458368
# memori akhir:  12630458368
# Testing image number:  44
# memori awal:  12630458368
# memori akhir:  12630458368
# Testing image number:  45
# memori awal:  12630458368
# memori akhir:  12630458368
# Testing image number:  46
# memori awal:  12630458368
# memori akhir:  12630458368
# Testing image number:  47
# memori awal:  12630458368
# memori akhir:  12630458368
# Testing image number:  48
# memori awal:  12630458368
# memori akhir:  12630458368
# Testing image number:  49
# memori awal:  12630458368
# memori akhir:  12630458368
# Testing image number:  50
# memori awal:  12630470656
# memori akhir:  12630470656
# Testing image number:  51
# memori awal:  12630470656
# memori akhir:  12630470656
# Testing image number:  52
# memori awal:  12630470656
# memori akhir:  12630470656
# Testing image number:  53
# memori awal:  12630470656
# memori akhir:  12630470656
# Testing image number:  54
# memori awal:  12630470656
# memori akhir:  12630470656
# Testing image number:  55
# memori awal:  12630470656
# memori akhir:  12630470656
# Testing image number:  56
# memori awal:  12630470656
# memori akhir:  12630470656
# Testing image number:  57
# memori awal:  12630470656
# memori akhir:  12630470656
# Testing image number:  58
# memori awal:  12630470656
# memori akhir:  12630470656
# Testing image number:  59
# memori awal:  12630470656
# memori akhir:  12630470656
# Testing image number:  60
# memori awal:  12630470656
# memori akhir:  12630470656
# Testing image number:  61
# memori awal:  12630470656
# memori akhir:  12630454272
# Testing image number:  62
# memori awal:  12630454272
# memori akhir:  12630454272
# Testing image number:  63
# memori awal:  12630454272
# memori akhir:  12630454272
# Testing image number:  64
# memori awal:  12630454272
# memori akhir:  12630454272
# Testing image number:  65
# memori awal:  12630454272
# memori akhir:  12630454272
# Testing image number:  66
# memori awal:  12630454272
# memori akhir:  12630454272
# Testing image number:  67
# memori awal:  12630454272
# memori akhir:  12630454272
# Testing image number:  68
# memori awal:  12630454272
# memori akhir:  12630454272
# Testing image number:  69
# memori awal:  12630454272
# memori akhir:  12630454272
# Testing image number:  70
# memori awal:  12630454272
# memori akhir:  12630454272
# Testing image number:  71
# memori awal:  12630454272
# memori akhir:  12630454272
# Testing image number:  72
# memori awal:  12630454272
# memori akhir:  12630454272
# Testing image number:  73
# memori awal:  12630454272
# memori akhir:  12630454272
# Testing image number:  74
# memori awal:  12630454272
# memori akhir:  12630454272
# Testing image number:  75
# memori awal:  12630454272
# memori akhir:  12630970368
# Testing image number:  76
# memori awal:  12629905408
# memori akhir:  12630695936
# Testing image number:  77
# memori awal:  12630294528
# memori akhir:  12629372928
# Testing image number:  78
# memori awal:  12630441984
# memori akhir:  12630970368
# Testing image number:  79
# memori awal:  12629889024
# memori akhir:  12630048768
# Testing image number:  80
# memori awal:  12629516288
# memori akhir:  12630568960
# Testing image number:  81
# memori awal:  12630581248
# memori akhir:  12630581248
# Testing image number:  82
# memori awal:  12630589440
# memori akhir:  12630589440
# Testing image number:  83
# memori awal:  12630589440
# memori akhir:  12630589440
# Testing image number:  84
# memori awal:  12630589440
# memori akhir:  12630589440
# Testing image number:  85
# memori awal:  12630589440
# memori akhir:  12630589440
# Testing image number:  86
# memori awal:  12630589440
# memori akhir:  12630589440
# Testing image number:  87
# memori awal:  12630589440
# memori akhir:  12630589440
# Testing image number:  88
# memori awal:  12630589440
# memori akhir:  12630589440
# Testing image number:  89
# memori awal:  12630589440
# memori akhir:  12630589440
# Testing image number:  90
# memori awal:  12630589440
# memori akhir:  12630589440
# Testing image number:  91
# memori awal:  12630589440
# memori akhir:  12630589440
# Testing image number:  92
# memori awal:  12630593536
# memori akhir:  12630855680
# Testing image number:  93
# memori awal:  12630855680
# memori akhir:  12630855680
# Testing image number:  94
# memori awal:  12629684224
# memori akhir:  12630736896
# Testing image number:  95
# memori awal:  12629684224
# memori akhir:  12630736896
# Testing image number:  96
# memori awal:  12629684224
# memori akhir:  12630736896
# Testing image number:  97
# memori awal:  12629684224
# memori akhir:  12630736896
# Testing image number:  98
# memori awal:  12629684224
# memori akhir:  12630736896
# Testing image number:  99
# memori awal:  12629684224
# memori akhir:  12630736896
# Testing image number:  100
# memori awal:  12629684224
# memori akhir:  12630736896
# [STOP]
# Testing completed.
#
# [RESULT]
# Average memory used per image: 146.08 KB
# Average time taken per image: 4.63 seconds

# %% [markdown]
# # Testing SVM

# %%
# Load model SVM
SVMclf = r"C:\Users\SMSK_Narinda\Desktop\Skripsi_Checkpoint_KNN_SVM_Dermnet\Model\SVM_71_Classifier.p"
modelSVM = pickle.load(open( SVMclf ,'rb'))

# %%
# Load Label
datadir= r"C:\Users\SMSK_Narinda\Desktop\Research\dataset"

# %%
Categories=[]

subfolders= [os.path.join(datadir, d) for d in os.listdir(datadir) if os.path.isdir(os.path.join(datadir, d))]
for label in os.listdir(datadir):
    Categories.append(label)

# %%
# Preprocessing SVM
def transform_labels(labels):
    label_mapping = {label: idx for idx, label in enumerate(np.unique(labels))}
    return np.array([label_mapping[label] for label in labels]), label_mapping

# def inverse_transform_labels(predictions, label_mapping):
#     inverse_mapping = {v: k for k, v in label_mapping.items()}
#     return np.array([inverse_mapping[int(round(pred))] for pred in predictions])

def inverse_transform_labels(predictions, label_mapping):
    inverse_mapping = {v: k for k, v in label_mapping.items()}
    transformed_labels = []
    for pred in predictions:
        rounded_pred = int(round(pred))
        if rounded_pred in inverse_mapping:
            transformed_labels.append(inverse_mapping[rounded_pred])
        else:
            print(f"Unexpected prediction value: {rounded_pred}")
            transformed_labels.append("Unknown")  # Or handle it appropriately
    return np.array(transformed_labels)

# %%
# Transformasi label
labels_train_transformed, label_mapping = transform_labels(Categories)

# %%
print("Label Mapping:", label_mapping)
# Out:
# Label Mapping: {'Acne and Rosacea Photos': 0, 'Actinic Keratosis Basal Cell Carcinoma and other Malignant Lesions': 1, 'Atopic Dermatitis Photos': 2, 'Bullous Disease Photos': 3, 'Cellulitis Impetigo and other Bacterial Infections': 4, 'Eczema Photos': 5, 'Exanthems and Drug Eruptions': 6, 'Hair Loss Photos Alopecia and other Hair Diseases': 7, 'Herpes HPV and other STDs Photos': 8, 'Light Diseases and Disorders of Pigmentation': 9, 'Lupus and other Connective Tissue diseases': 10, 'Melanoma Skin Cancer Nevi and Moles': 11, 'Nail Fungus and other Nail Disease': 12, 'Poison Ivy Photos and other Contact Dermatitis': 13, 'Psoriasis pictures Lichen Planus and related diseases': 14, 'Scabies Lyme Disease and other Infestations and Bites': 15, 'Seborrheic Keratoses and other Benign Tumors': 16, 'Systemic Disease': 17, 'Tinea Ringworm Candidiasis and other Fungal Infections': 18, 'Urticaria Hives': 19, 'Vascular Tumors': 20, 'Vasculitis Photos': 21, 'Warts Molluscum and other Viral Infections': 22}

# %%
print('[START]')

for idx, filename in enumerate(os.scandir(img_test_path)):
    if filename.is_file():
        print("Testing image number: ", idx+1)
        # Store image number and filename
        img_num.append(idx + 1)
        img_name.append(filename.name)
        
        # Get image's path from object filename
        image_path = filename.path
        
        # Read image from image_path 
        image = cv2.imread(image_path)
        
        # Resize image to the desired size
        image = cv2.resize(image, (150, 150))
        image = image.flatten()
        image = np.array(image)
        
        # Measure memory and time for prediction
        current_process = psutil.Process(os.getpid())
        mem_start = current_process.memory_info().rss
        start_time = time.time()
        
        # Perform predictio
        predictions = modelSVM.predict([image])
        predicted_labels = inverse_transform_labels(predictions, label_mapping)
        prediction.append(predicted_labels)
        
        end_time = time.time()
        mem_end = current_process.memory_info().rss

        print("memori awal: ", mem_start)
        print("memori akhir: ", mem_end)
        
        memory_usage.append((mem_end - mem_start) / 1024)  # Memory usage in KB
        time_taken.append(end_time - start_time)  # Time taken in seconds

# Calculate average memory and time
avg_memory = sum(memory_usage) / len(memory_usage) if memory_usage else 0
avg_time = sum(time_taken) / len(time_taken) if time_taken else 0

print('[STOP]')
print("Testing completed.")
print("")
print("[RESULT]")
print(f'Average memory used per image: {avg_memory:.2f} KB')
print(f'Average time taken per image: {avg_time:.2f} seconds')
# Out:
# [START]
# Testing image number:  1
# memori awal:  15090405376
# memori akhir:  15090479104
# Testing image number:  2
# memori awal:  15090479104
# memori akhir:  15090479104
# Testing image number:  3
# memori awal:  15090479104
# memori akhir:  15090479104
# Testing image number:  4
# memori awal:  15090442240
# memori akhir:  15090442240
# Testing image number:  5
# memori awal:  15091482624
# memori akhir:  15091482624
# Testing image number:  6
# memori awal:  15089442816
# memori akhir:  15089442816
# Testing image number:  7
# memori awal:  15090462720
# memori akhir:  15090462720
# Testing image number:  8
# memori awal:  15090462720
# memori akhir:  15090462720
# Testing image number:  9
# memori awal:  15090462720
# memori akhir:  15090462720
# Testing image number:  10
# memori awal:  15090462720
# memori akhir:  15090462720
# Testing image number:  11
# memori awal:  15089442816
# memori akhir:  15089442816
# Testing image number:  12
# memori awal:  15090466816
# memori akhir:  15090466816
# Testing image number:  13
# memori awal:  15090466816
# memori akhir:  15090466816
# Testing image number:  14
# memori awal:  15090466816
# memori akhir:  15090466816
# Testing image number:  15
# memori awal:  15090466816
# memori akhir:  15090466816
# Testing image number:  16
# memori awal:  15090466816
# memori akhir:  15090466816
# Testing image number:  17
# memori awal:  15090466816
# memori akhir:  15090466816
# Testing image number:  18
# memori awal:  15090466816
# memori akhir:  15090466816
# Testing image number:  19
# memori awal:  15090466816
# memori akhir:  15090466816
# Testing image number:  20
# memori awal:  15090466816
# memori akhir:  15090466816
# Testing image number:  21
# memori awal:  15090466816
# memori akhir:  15090466816
# Testing image number:  22
# memori awal:  15089442816
# memori akhir:  15089442816
# Testing image number:  23
# memori awal:  15090458624
# memori akhir:  15090458624
# Testing image number:  24
# memori awal:  15090458624
# memori akhir:  15090458624
# Testing image number:  25
# memori awal:  15089442816
# memori akhir:  15089442816
# Testing image number:  26
# memori awal:  15090470912
# memori akhir:  15090470912
# Testing image number:  27
# memori awal:  15090470912
# memori akhir:  15090470912
# Testing image number:  28
# memori awal:  15089442816
# memori akhir:  15089442816
# Testing image number:  29
# memori awal:  15090462720
# memori akhir:  15090462720
# Testing image number:  30
# memori awal:  15090462720
# memori akhir:  15090462720
# Testing image number:  31
# memori awal:  15090462720
# memori akhir:  15090462720
# Testing image number:  32
# memori awal:  15090462720
# memori akhir:  15090462720
# Testing image number:  33
# memori awal:  15089442816
# memori akhir:  15089442816
# Testing image number:  34
# memori awal:  15090483200
# memori akhir:  15090483200
# Testing image number:  35
# memori awal:  15090483200
# memori akhir:  15090483200
# Testing image number:  36
# memori awal:  15090483200
# memori akhir:  15090483200
# Testing image number:  37
# memori awal:  15090483200
# memori akhir:  15090483200
# Testing image number:  38
# memori awal:  15090483200
# memori akhir:  15090483200
# Testing image number:  39
# memori awal:  15090483200
# memori akhir:  15090483200
# Testing image number:  40
# memori awal:  15090483200
# memori akhir:  15090483200
# Testing image number:  41
# memori awal:  15090483200
# memori akhir:  15090483200
# Testing image number:  42
# memori awal:  15090483200
# memori akhir:  15090483200
# Testing image number:  43
# memori awal:  15090483200
# memori akhir:  15090483200
# Testing image number:  44
# memori awal:  15090483200
# memori akhir:  15090483200
# Testing image number:  45
# memori awal:  15090483200
# memori akhir:  15090483200
# Testing image number:  46
# memori awal:  15090483200
# memori akhir:  15090483200
# Testing image number:  47
# memori awal:  15090483200
# memori akhir:  15090483200
# Testing image number:  48
# memori awal:  15090495488
# memori akhir:  15090495488
# Testing image number:  49
# memori awal:  15090495488
# memori akhir:  15090495488
# Testing image number:  50
# memori awal:  15090495488
# memori akhir:  15090495488
# Testing image number:  51
# memori awal:  15090495488
# memori akhir:  15090495488
# Testing image number:  52
# memori awal:  15090495488
# memori akhir:  15090495488
# Testing image number:  53
# memori awal:  15090495488
# memori akhir:  15090495488
# Testing image number:  54
# memori awal:  15090495488
# memori akhir:  15090495488
# Testing image number:  55
# memori awal:  15090495488
# memori akhir:  15090495488
# Testing image number:  56
# memori awal:  15090495488
# memori akhir:  15090495488
# Testing image number:  57
# memori awal:  15090495488
# memori akhir:  15090495488
# Testing image number:  58
# memori awal:  15090495488
# memori akhir:  15090495488
# Testing image number:  59
# memori awal:  15090495488
# memori akhir:  15090495488
# Testing image number:  60
# memori awal:  15090495488
# memori akhir:  15090495488
# Testing image number:  61
# memori awal:  15090495488
# memori akhir:  15090495488
# Testing image number:  62
# memori awal:  15090495488
# memori akhir:  15090495488
# Testing image number:  63
# memori awal:  15090495488
# memori akhir:  15090495488
# Testing image number:  64
# memori awal:  15090495488
# memori akhir:  15090495488
# Testing image number:  65
# memori awal:  15090495488
# memori akhir:  15090495488
# Testing image number:  66
# memori awal:  15090495488
# memori akhir:  15090495488
# Testing image number:  67
# memori awal:  15090495488
# memori akhir:  15090495488
# Testing image number:  68
# memori awal:  15090495488
# memori akhir:  15090495488
# Testing image number:  69
# memori awal:  15090495488
# memori akhir:  15090495488
# Testing image number:  70
# memori awal:  15090495488
# memori akhir:  15090495488
# Testing image number:  71
# memori awal:  15090495488
# memori akhir:  15090495488
# Testing image number:  72
# memori awal:  15090495488
# memori akhir:  15090495488
# Testing image number:  73
# memori awal:  15090495488
# memori akhir:  15090495488
# Testing image number:  74
# memori awal:  15090495488
# memori akhir:  15090495488
# Testing image number:  75
# memori awal:  15090495488
# memori akhir:  15090495488
# Testing image number:  76
# memori awal:  15090495488
# memori akhir:  15090495488
# Testing image number:  77
# memori awal:  15090495488
# memori akhir:  15090495488
# Testing image number:  78
# memori awal:  15090495488
# memori akhir:  15090495488
# Testing image number:  79
# memori awal:  15090495488
# memori akhir:  15090495488
# Testing image number:  80
# memori awal:  15090495488
# memori akhir:  15090495488
# Testing image number:  81
# memori awal:  15090495488
# memori akhir:  15090495488
# Testing image number:  82
# memori awal:  15090495488
# memori akhir:  15090495488
# Testing image number:  83
# memori awal:  15090495488
# memori akhir:  15090495488
# Testing image number:  84
# memori awal:  15090495488
# memori akhir:  15090495488
# Testing image number:  85
# memori awal:  15090495488
# memori akhir:  15090495488
# Testing image number:  86
# memori awal:  15090495488
# memori akhir:  15090495488
# Testing image number:  87
# memori awal:  15090495488
# memori akhir:  15090495488
# Testing image number:  88
# memori awal:  15090495488
# memori akhir:  15090495488
# Testing image number:  89
# memori awal:  15090495488
# memori akhir:  15090495488
# Testing image number:  90
# memori awal:  15090495488
# memori akhir:  15090495488
# Testing image number:  91
# memori awal:  15090495488
# memori akhir:  15090495488
# Testing image number:  92
# memori awal:  15090495488
# memori akhir:  15090495488
# Testing image number:  93
# memori awal:  15090495488
# memori akhir:  15090495488
# Testing image number:  94
# memori awal:  15089455104
# memori akhir:  15089455104
# Testing image number:  95
# memori awal:  15090483200
# memori akhir:  15090483200
# Testing image number:  96
# memori awal:  15090483200
# memori akhir:  15090483200
# Testing image number:  97
# memori awal:  15089455104
# memori akhir:  15089455104
# Testing image number:  98
# memori awal:  15090475008
# memori akhir:  15090475008
# Testing image number:  99
# memori awal:  15090475008
# memori akhir:  15090475008
# Testing image number:  100
# memori awal:  15090475008
# memori akhir:  15090475008
# [STOP]
# Testing completed.
#
# [RESULT]
# Average memory used per image: 0.72 KB
# Average time taken per image: 0.48 seconds

# %% [markdown]
# # Hasil Analisis

# %%
print(f'Summary of Memory Usage: {sum(memory_usage)} KB')
print(f'Summary of Duration: {sum(time_taken)} seconds')
# Out:
# Summary of Memory Usage: 72.0 KB
# Summary of Duration: 48.033674478530884 seconds

# %%
# Information prints
# Prepare data for tabulate
table_data = [["No.", "Filename", "Memory usage", "Time taken"],
              *zip(range(1, len(memory_usage) + 1), img_name, memory_usage, time_taken)]

# Print table using tabulate, with transposed data
print(tabulate(table_data, headers="firstrow", tablefmt="plain"))
# Out:
#   No.  Filename                                    Memory usage    Time taken
#     1  03Eczema0310.jpg                                      72      0.47603
#     2  03EczemaAreolae021223.jpg                              0      0.469638
#     3  03EczemaAreolae1.jpg                                   0      0.490669
#     4  08lichenPlanusTongue112205.jpg                         0      0.476028
#     5  08lichenPlanusTongue1122051.jpg                        0      0.492622
#     6  08lichenPlanusTongue1122052.jpg                        0      0.479937
#     7  08LSAAnal062804.jpg                                    0      0.480912
#     8  08LSASkin.jpg                                          0      0.469206
#     9  acne-keloidalis-25.jpg                                 0      0.460859
#    10  acne-keloidalis-26.jpg                                 0      0.462367
#    11  actinic-cheilitis-sq-cell-lip-3.jpg                    0      0.476042
#    12  actinic-cheilitis-sq-cell-lip-4.jpg                    0      0.465738
#    13  actinic-cheilitis-sq-cell-lip-8.jpg                    0      0.472123
#    14  actinic-cheilitis-sq-cell-lip-9.jpg                    0      0.473107
#    15  acute-paronychia-10.jpg                                0      0.472127
#    16  acute-paronychia-11.jpg                                0      0.471596
#    17  acute-paronychia-12.jpg                                0      0.473102
#    18  acute-paronychia-8.jpg                                 0      0.465295
#    19  acute-paronychia-9.jpg                                 0      0.472127
#    20  AIDS-47.jpg                                            0      0.484286
#    21  AIDS-48.jpg                                            0      0.476028
#    22  AIDS-49.jpg                                            0      0.473318
#    23  AIDS-50.jpg                                            0      0.493045
#    24  AIDS-56.jpg                                            0      0.495005
#    25  AIDS-57.jpg                                            0      0.47611
#    26  AIDS-59.jpg                                            0      0.477086
#    27  allergic-contact-dermatitis-83.jpg                     0      0.48097
#    28  allergic-contact-dermatitis-84.jpg                     0      0.489009
#    29  allergic-contact-dermatitis-85.jpg                     0      0.479987
#    30  allergic-contact-dermatitis-89.jpg                     0      0.482239
#    31  allergic-contact-dermatitis-91.jpg                     0      0.473899
#    32  angiokeratomas-10.jpg                                  0      0.478924
#    33  angiokeratomas-11.jpg                                  0      0.480001
#    34  angiokeratomas-12.jpg                                  0      0.476065
#    35  angiokeratomas-3.jpg                                   0      0.48322
#    36  angiokeratomas-4.jpg                                   0      0.487984
#    37  angiokeratomas-5.jpg                                   0      0.479975
#    38  atypical-nevi-20.jpg                                   0      0.481962
#    39  atypical-nevi-21.jpg                                   0      0.485095
#    40  atypical-nevi-22.jpg                                   0      0.488653
#    41  atypical-nevi-23.jpg                                   0      0.476789
#    42  atypical-nevi-24.jpg                                   0      0.481267
#    43  atypical-nevi-25.jpg                                   0      0.4762
#    44  benign-familial-chronic-pemphigus-12.jpg               0      0.483828
#    45  benign-familial-chronic-pemphigus-6.jpg                0      0.497876
#    46  candidiasis-large-skin-folds-144.jpg                   0      0.485567
#    47  candidiasis-large-skin-folds-145.jpg                   0      0.486107
#    48  candidiasis-large-skin-folds-150.jpg                   0      0.478843
#    49  candidiasis-large-skin-folds-151.jpg                   0      0.499054
#    50  chapped-fissured-feet-30.jpg                           0      0.503118
#    51  chapped-fissured-feet-31.jpg                           0      0.483978
#    52  chigger-Bites-Bullous-.jpg                             0      0.47587
#    53  chigger-bites-bullous-2.jpg                            0      0.482538
#    54  chilblains-perniosis-10.jpg                            0      0.479087
#    55  chilblains-perniosis-11.jpg                            0      0.47406
#    56  chilblains-perniosis-15.jpg                            0      0.474174
#    57  chilblains-perniosis-16.jpg                            0      0.478038
#    58  chilblains-perniosis-24.jpg                            0      0.487055
#    59  chilblains-perniosis-30.jpg                            0      0.47118
#    60  chilblains-perniosis-31.jpg                            0      0.470002
#    61  chilblains-perniosis-32.jpg                            0      0.479024
#    62  chilblains-perniosis-9.jpg                             0      0.493729
#    63  chondrodermatitis-nodularis-19.jpg                     0      0.488231
#    64  chondrodermatitis-nodularis-20.jpg                     0      0.486306
#    65  chondrodermatitis-nodularis-21.jpg                     0      0.490004
#    66  chondrodermatitis-nodularis-22.jpg                     0      0.486398
#    67  Coral-Poisoning-1.jpg                                  0      0.490879
#    68  corns-17.jpg                                           0      0.489592
#    69  corns-18.jpg                                           0      0.480164
#    70  corns-19.jpg                                           0      0.491949
#    71  dermagraphism-31.jpg                                   0      0.476859
#    72  dermagraphism-32.jpg                                   0      0.472915
#    73  dermagraphism-33.jpg                                   0      0.475985
#    74  dermagraphism-38.jpg                                   0      0.480125
#    75  dermagraphism-39.jpg                                   0      0.479706
#    76  drug-eruptions-79.jpg                                  0      0.472865
#    77  Folliculitis-28.jpg                                    0      0.471944
#    78  Folliculitis-Gram-Negative-1.jpg                       0      0.476102
#    79  Furuncles-Carbuncles-5.jpg                             0      0.484136
#    80  Furuncles-Carbuncles-6.jpg                             0      0.472861
#    81  granuloma-annulare-137.jpg                             0      0.473176
#    82  hydroa-vacciniforme-1.jpg                              0      0.477978
#    83  hydroa-vacciniforme-2.jpg                              0      0.485154
#    84  hydroa-vacciniforme-3.jpg                              0      0.470892
#    85  hydroa-vacciniforme-4.jpg                              0      0.480378
#    86  polyarteritis-nodosa-1.jpg                             0      0.476239
#    87  polyarteritis-nodosa-2.jpg                             0      0.47913
#    88  pyoderma-gangrenosum-4.jpg                             0      0.473947
#    89  pyoderma-gangrenosum-5.jpg                             0      0.475782
#    90  pyoderma-gangrenosum-6.jpg                             0      0.475918
#    91  rosacea-23.jpg                                         0      0.478395
#    92  rosacea-6.jpg                                          0      0.477652
#    93  rosacea-78.jpg                                         0      0.476143
#    94  rosacea-81.jpg                                         0      0.485976
#    95  rosacea-90.jpg                                         0      0.488047
#    96  rosacea-nose-33.jpg                                    0      0.501006
#    97  rosacea-nose-36.jpg                                    0      0.489716
#    98  rosacea-steroid-6.jpg                                  0      0.490019
#    99  sarcoid-28.jpg                                         0      0.484071
#   100  sarcoid-29.jpg                                         0      0.487267

# %%
# Plotting memory and time
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.plot(memory_usage, label='Memory Usage (KB)')
plt.xlabel('Image Index')
plt.ylabel('Memory (KB)')
plt.title('Memory Usage per Image')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(time_taken, label='Time Taken (s)')
plt.xlabel('Image Index')
plt.ylabel('Time (s)')
plt.title('Time Taken per Image')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Write in Excel

# %% [markdown]
# Note:
# - write_row(row, column, data)
# - write_column(row, column, data)
# - worksheet.write(0, 1, "Hello")
# - worksheet.write(0, 2, "World")
#
# https://stackoverflow.com/questions/31909722/how-to-write-python-array-into-excel-spread-sheet

# %%
# Buka file Excel yang sudah ada
filepath = r"C:\Users\SMSK_Narinda\Desktop\Skripsi_Checkpoint_KNN_SVM_Dermnet\Testing_Result.xlsx"
workbook = load_workbook(filepath)
predictions_str = [pred[0] for pred in prediction]

# Tambahkan sheet baru
new_sheet_name = "Test_SVM_label"  # Ganti dengan nama sheet yang diinginkan
worksheet = workbook.create_sheet(title=new_sheet_name)

# Menulis data ke sheet baru
worksheet.append(["Image Number", "Image Name", "Memory Usage", "Time Taken", "Prediction"])  # Header
for i in range(len(img_num)):
    worksheet.append([img_num[i], img_name[i], memory_usage[i], time_taken[i], predictions_str[i]])

# Simpan workbook kembali
workbook.save(filepath)

# %%
print(len(img_num))
print(len(img_name))
print(len(time_taken))
print(len(predictions_str))

# %% [markdown]
# ## Simple Example

# %%
workbook = xlsxwriter.Workbook(r"C:\Users\SMSK_Narinda\Desktop\test_hasil.xlsx")
worksheet = workbook.add_worksheet()
predictions_str = [pred[0] for pred in prediction]

worksheet.write_column(1, 1, img_num)
worksheet.write_column(1, 2, img_name)
worksheet.write_column(1, 3, memory_usage)
worksheet.write_column(1, 4, time_taken)
worksheet.write_column(1, 5, predictions_str)

workbook.close()

# %%
# for filename in os.scandir(img_test_path):
#             if filename.is_file():
#                 # Get image's path from object filename
#                 image_path = filename.path
                
#                 # Get image's filename
#                 image = filename
                
#                 # Read image from image_path 
#                 image = cv2.imread(image_path)
                
#                 # Get label from the subfolder name 
#                 label = classes.split(os.path.sep)[-1]
    
#                 # Use extract_color_histogram function
#                 # Features extraction from color histogram image 
#                 hist = extract_color_histogram(image)
    
#                 # Add to list
#                 features.append(hist)
#                 labels.append(label)

# %%
for i in range (1,10):
    start_time = time.time()
    img_num.append(i)
    for y in range (1,10):
        memory.append(y)
    # duration.append('%.100f' % (time.time() - start_time))

# %%
# print(memory)
# print(duration)
